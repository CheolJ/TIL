# %%
import plotly.offline as plyo
import cufflinks
import numpy as np
import pandas as pd

# %%
data = np.random.standard_normal((150, 5)).cumsum(axis=0)
index = pd.date_range('2021-1-1', freq='B', periods=len(data))
df = pd.DataFrame(100+5*data, columns=list('abcde'), index=index)
df.head()
# Out:
#                      a          b          c           d           e
# 2021-01-01   99.927177  92.051043  98.731585   96.918389  112.402073
# 2021-01-04   96.663125  81.797021  95.584305  100.439543  103.438219
# 2021-01-05   97.704201  80.534344  86.142427  105.367353  111.973843
# 2021-01-06   99.289067  71.725274  94.428477  108.476497  111.374255
# 2021-01-07  103.756339  71.519082  99.180389  105.773847  107.849422

# %%
plyo.iplot(df.iplot(asFigure=True))
