# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# Data load
path = './data/raw_data_0304_160Mbps_5sec.cap0'
raw_data = np.fromfile(path, dtype='int16')

# %%
# Variables
data_num = len(raw_data)
time = 5
x_time = np.arange(0, time, time/data_num)

# %%
plt.figure(figsize=(21, 12))
plt.plot(x_time[2000:6000], raw_data[2000:6000])

# %%
# DAE
input_data = tf.keras.input(shape=(200,))

encoded = tf.keras.layers.Dense(units=25, activation='sigmoid', input_shape=(200,))(input_data)

decoded = tf.keras.layers.Dense(units=200, activation='sigmoid')(encoded)


ANN_AE = tf.keras.Model(input_data, decoded)
ANN_AE.compile(optimizer='adam', loss='mae')
cp_callback = tf.keras.callbacks.ModelCheckpoint(CHECKPOINT_PATH, verbose=1, save_weights_only=True, period=100)
