# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as sgl
import reference_signal as rsgl

# %%
timepsace, signal, signal_e, id_chain = rsgl.merge_signal_by_id(9930)

# %%
len(signal)
# Out:
# 8936960

# %%
standard = 25000000
id = 99300

residual = standard - id * 2

# %%
import random
st = random.randrange(residual)
signal = np.append(np.zeros(st), signal)
signal = np.append(signal, np.zeros(residual-st))

plt.figure(figsize=(30,5))
plt.plot(signal)

plt.show()
