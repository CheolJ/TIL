# %%
import reference_signal as rs

# %%
13459.7 + 7999.99
# Out:
# 21459.690000000002

# %%
timespace, signal, signal_e, id_chain = rs.gen_ref_window_by_id(id=7430)
# Out:
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001
#
#
# status, site : master Rongcheng
# length of timespace : 1000001 || length of signal : 1000001 || length of signal_e : 1000001
# master process over; next_start_time : 10000
#
# status, site : slave Xuancheng
# slave process; end time : 13459.7
#
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 10000 end time : 13459.7
#
# shape of temp : (345971,) shape of temp_signal : (345971,)
# last temp : 13459.7 last -1 temp : 13459.69
# before last timespace : 10000.0 before last -1 timespace : 9999.99
#
# after last timespace : 13459.7 after last -1 timespace 13459.69
#
# length of timespace : 1345971 || length of signal : 1345971 || length of signal_e : 1345971
#
# add slave window
# ----------------------------------
#
# timespace_s : 8000.0 timespace_s -1 : 7999.99
# last temp : 21459.7 last -1 temp : 21459.690000000002
#
# ----------------------------------
# length of timespace : 2145972 || length of signal : 2145972 || length of signal_e : 2145972
# slave process over; start_time : 21459.7
# last time : 21459.7 last -1 time : 21459.690000000002
#
# status, site : slave Helong
# slave process; end time : 30852.32
#
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 21459.7 end time : 30852.32
#
# shape of temp : (939262,) shape of temp_signal : (939262,)
# last temp : 30852.32 last -1 temp : 30852.309999989353
# before last timespace : 21459.7 before last -1 timespace : 21459.690000000002
#
# after last timespace : 30852.32 after last -1 timespace 30852.309999989353
#
# length of timespace : 3085233 || length of signal : 3085233 || length of signal_e : 3085233
#
# add slave window
# ----------------------------------
#
# timespace_s : 8000.0 timespace_s -1 : 7999.99
# last temp : 38852.32 last -1 temp : 38852.31
#
# ----------------------------------
# length of timespace : 3885234 || length of signal : 3885234 || length of signal_e : 3885234
# slave process over; start_time : 38852.32
# last time : 38852.32 last -1 time : 38852.31
#
#
# iteration over
# --------------------------------------------------
#
# last time : 74299.98999999999 last -1 time : 74299.98000000001
# standard_time : 74300
# length of timespace : 7430001 || length of signal : 7430001 || length of signal_e : 7430001
#
# --------------------------------------------------
#
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001
#
#
# status, site : master Rongcheng
# length of timespace : 8430002 || length of signal : 8430002 || length of signal_e : 8430002
# master process over; next_start_time : 84300
#
# status, site : slave Xuancheng
# slave process; end time : 87759.7
#
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 84300 end time : 87759.7
#
# shape of temp : (345970,) shape of temp_signal : (345970,)
# last temp : 87759.7 last -1 temp : 87759.68999997109
# before last timespace : 84300.0 before last -1 timespace : 84299.99
#
# after last timespace : 87759.7 after last -1 timespace 87759.68999997109
#
# length of timespace : 8775971 || length of signal : 8775971 || length of signal_e : 8775971
#
# add slave window
# ----------------------------------
#
# timespace_s : 8000.0 timespace_s -1 : 7999.99
# last temp : 95759.7 last -1 temp : 95759.69
#
# ----------------------------------
# length of timespace : 9575972 || length of signal : 9575972 || length of signal_e : 9575972
# slave process over; start_time : 95759.7
# last time : 95759.7 last -1 time : 95759.69
#
# status, site : slave Helong
# slave process; end time : 105152.32
#
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 95759.7 end time : 105152.32
#
# shape of temp : (939263,) shape of temp_signal : (939263,)
# last temp : 105152.32 last -1 temp : 105152.31000000001
# before last timespace : 95759.7 before last -1 timespace : 95759.69
#
# after last timespace : 105152.32 after last -1 timespace 105152.31000000001
#
# length of timespace : 10515234 || length of signal : 10515234 || length of signal_e : 10515234
#
# add slave window
# ----------------------------------
#
# timespace_s : 8000.0 timespace_s -1 : 7999.99
# last temp : 113152.32 last -1 temp : 113152.31000000001
#
# ----------------------------------
# length of timespace : 11315235 || length of signal : 11315235 || length of signal_e : 11315235
# slave process over; start_time : 113152.32
# last time : 113152.32 last -1 time : 113152.31000000001
#
#
# iteration over
# --------------------------------------------------
#
# last time : 148600.0 last -1 time : 148599.9899999972
# standard_time : 148600
# length of timespace : 14860002 || length of signal : 14860002 || length of signal_e : 14860002
#
# --------------------------------------------------

# %%
timespace, master_window, master_window_e = rs.gen_master_signal()
# Out:
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001

# %%
import matplotlib.pyplot as plt

fig, (loran_c, envelope, together) = plt.subplots(3, 1, figsize=(30,15), sharex=True)
plt.suptitle("Master Reference Signal\ndefault", fontsize=30)

# Loran-c signal at master reference signal
loran_c.plot(timespace, master_window, 'k', label='loran_c pulse\nat slave reference signal')

loran_c.set_ylabel("Normalized Amplitude", fontsize=15)
loran_c.legend(loc='upper right')

# Envelop signal at master reference signal
envelope.plot(timespace, master_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

envelope.set_ylabel("Normalized Amplitude", fontsize=15)
envelope.legend(loc='upper right')

# Loran-C and Envelop signal at master reference signal
together.plot(timespace, master_window, 'k', label='loran_c pulse\nat slave reference signal')
together.plot(timespace, master_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

together.set_xlabel("time($10^{-2}\mu s$)", fontsize=15)
together.set_ylabel("Normalized Amplitude", fontsize=15)
together.legend(loc='upper right')

plt.show()

# %%
timespace, master_window, master_window_e = rs.gen_master_signal(['+', '+', '-', '-', '+', '-', '+', '-', 'dummy', '+'])
# Out:
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001

# %%
import matplotlib.pyplot as plt

fig, (loran_c, envelope, together) = plt.subplots(3, 1, figsize=(30,15), sharex=True)
plt.suptitle("Master Reference Signal\nwtih GRI-A phase code", fontsize=30)

# Loran-c signal at master reference signal
loran_c.plot(timespace, master_window, 'k', label='loran_c pulse\nat slave reference signal')

loran_c.set_ylabel("Normalized Amplitude", fontsize=15)
loran_c.legend(loc='upper right')

# Envelop signal at master reference signal
envelope.plot(timespace, master_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

envelope.set_ylabel("Normalized Amplitude", fontsize=15)
envelope.legend(loc='upper right')

# Loran-C and Envelop signal at master reference signal
together.plot(timespace, master_window, 'k', label='loran_c pulse\nat slave reference signal')
together.plot(timespace, master_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

together.set_xlabel("time($10^{-2}\mu s$)", fontsize=15)
together.set_ylabel("Normalized Amplitude", fontsize=15)
together.legend(loc='upper right')

# %%
timespace, slave_window, slave_window_e = rs.gen_slave_signal()

# %%
import matplotlib.pyplot as plt

fig, (loran_c, envelope, together) = plt.subplots(3, 1, figsize=(30,15), sharex=True)
plt.suptitle("Slave Reference Signal\ndefault", fontsize=30)

# Loran-c signal at slave reference signal
loran_c.plot(timespace, slave_window, 'k', label='loran_c pulse\nat slave reference signal')

loran_c.set_ylabel("Normalized Amplitude", fontsize=15)
loran_c.legend(loc='upper right')

# Envelop signal at slave reference signal
envelope.plot(timespace, slave_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

envelope.set_ylabel("Normalized Amplitude", fontsize=15)
envelope.legend(loc='upper right')

# Loran-C and Envelop signal at slave reference signal
together.plot(timespace, slave_window, 'k', label='loran_c pulse\nat slave reference signal')
together.plot(timespace, slave_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

together.set_xlabel("time($10^{-2}\mu s$)", fontsize=15)
together.set_ylabel("Normalized Amplitude", fontsize=15)
together.legend(loc='upper right')

plt.show()

# %%
timespace, slave_window, slave_window_e = rs.gen_slave_signal(['+', '+', '+', '+', '+', '-', '-', '+'])

# %%
import matplotlib.pyplot as plt

fig, (loran_c, envelope, together) = plt.subplots(3, 1, figsize=(30,15), sharex=True)
plt.suptitle("Slave Reference Signal\nwith GRI-A phase code", fontsize=30)

# Loran-c signal at slave reference signal
loran_c.plot(timespace, slave_window, 'k', label='loran_c pulse\nat slave reference signal')

loran_c.set_ylabel("Normalized Amplitude", fontsize=15)
loran_c.legend(loc='upper right')

# Envelop signal at slave reference signal
envelope.plot(timespace, slave_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

envelope.set_ylabel("Normalized Amplitude", fontsize=15)
envelope.legend(loc='upper right')

# Loran-C and Envelop signal at slave reference signal
together.plot(timespace, slave_window, 'k', label='loran_c pulse\nat slave reference signal')
together.plot(timespace, slave_window_e, 'tomato', label='Envelop pulse\nat slave reference signal')

together.set_xlabel("time($10^{-2}\mu s$)", fontsize=15)
together.set_ylabel("Normalized Amplitude", fontsize=15)
together.legend(loc='upper right')

plt.show()

# %%
# Out:
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001
#
#
# status, site : master Pohang
# length of timespace : 1000001 || length of signal : 1000001 || length of signal_e : 1000001
# master process over; next_start_time : 10000
#
# status, site : slave Kwangju
# slave process; end time : 11946.97
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 10000 end time : 11946.97
#
# shape of temp : (194697,) shape of temp_signal : (194697,)
# last temp : 11946.97 last -1 temp : 11946.959999948638
# before last timespace : 10000.0 before last -1 timespace : 9999.99
#
# after last timespace : 11946.97 after last -1 timespace 11946.959999948638
#
# length of timespace : 1194697 || length of signal : 1194697 || length of signal_e : 1194697
#
# length of timespace : 1994698 || length of signal : 1994698 || length of signal_e : 1994698
# slave process over; start_time : 19946.97
# last time : 19946.97 last -1 time : 19946.96
#
# status, site : slave Ussuriisk
# slave process; end time : 54162.44
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 19946.97 end time : 54162.44
#
# shape of temp : (3421548,) shape of temp_signal : (3421548,)
# last temp : 54162.44 last -1 temp : 54162.43
# before last timespace : 19946.97 before last -1 timespace : 19946.96
#
# after last timespace : 54162.44 after last -1 timespace 54162.43
#
# length of timespace : 5416245 || length of signal : 5416245 || length of signal_e : 5416245
#
# length of timespace : 6216246 || length of signal : 6216246 || length of signal_e : 6216246
# slave process over; start_time : 62162.44
# last time : 62162.44 last -1 time : 62162.43
#
# status, site : slave Incheon
# slave process; end time : 81352
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 62162.44 end time : 81352
#
# shape of temp : (1918956,) shape of temp_signal : (1918956,)
# last temp : 81352.0 last -1 temp : 81351.98999999478
# before last timespace : 62162.44 before last -1 timespace : 62162.43
#
# after last timespace : 81352.0 after last -1 timespace 81351.98999999478
#
# length of timespace : 8135201 || length of signal : 8135201 || length of signal_e : 8135201
#
# length of timespace : 8935202 || length of signal : 8935202 || length of signal_e : 8935202
# slave process over; start_time : 89352.0
# last time : 89352.0 last -1 time : 89351.99
#
#
# iteration over
# --------------------------------------------------
#
# last time : 99299.99 last -1 time : 99299.98
# standard_time : 99300
# length of timespace : 9930001 || length of signal : 9930001 || length of signal_e : 9930001
#
# --------------------------------------------------
#
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001
#
#
# status, site : master Pohang
# length of timespace : 10930002 || length of signal : 10930002 || length of signal_e : 10930002
# master process over; next_start_time : 109300
#
# status, site : slave Kwangju
# slave process; end time : 111246.97
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 109300 end time : 111246.97
#
# shape of temp : (194698,) shape of temp_signal : (194698,)
# last temp : 111246.97 last -1 temp : 111246.96
# before last timespace : 109300.0 before last -1 timespace : 109299.99
#
# after last timespace : 111246.97 after last -1 timespace 111246.96
#
# length of timespace : 11124699 || length of signal : 11124699 || length of signal_e : 11124699
#
# length of timespace : 11924700 || length of signal : 11924700 || length of signal_e : 11924700
# slave process over; start_time : 119246.97
# last time : 119246.97 last -1 time : 119246.96
#
# status, site : slave Ussuriisk
# slave process; end time : 153462.44
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 119246.97 end time : 153462.44
#
# shape of temp : (3421548,) shape of temp_signal : (3421548,)
# last temp : 153462.44 last -1 temp : 153462.43
# before last timespace : 119246.97 before last -1 timespace : 119246.96
#
# after last timespace : 153462.44 after last -1 timespace 153462.43
#
# length of timespace : 15346247 || length of signal : 15346247 || length of signal_e : 15346247
#
# length of timespace : 16146248 || length of signal : 16146248 || length of signal_e : 16146248
# slave process over; start_time : 161462.44
# last time : 161462.44 last -1 time : 161462.43
#
# status, site : slave Incheon
# slave process; end time : 180652
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 161462.44 end time : 180652
#
# shape of temp : (1918956,) shape of temp_signal : (1918956,)
# last temp : 180652.0 last -1 temp : 180651.98999999478
# before last timespace : 161462.44 before last -1 timespace : 161462.43
#
# after last timespace : 180652.0 after last -1 timespace 180651.98999999478
#
# length of timespace : 18065203 || length of signal : 18065203 || length of signal_e : 18065203
#
# length of timespace : 18865204 || length of signal : 18865204 || length of signal_e : 18865204
# slave process over; start_time : 188652.0
# last time : 188652.0 last -1 time : 188651.99
#
#
# iteration over
# --------------------------------------------------
#
# last time : 198600.0 last -1 time : 198599.99
# standard_time : 198600
# length of timespace : 19860004 || length of signal : 19860004 || length of signal_e : 19860004
#
# --------------------------------------------------

# %%
a = [1,2,3,4,5]

# %%
a[1:-1]
# Out:
# [2, 3, 4]

# %%
timespace, signal, signal_e, id_chain = rs.gen_ref_window_by_id(id=7430)
# Out:
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001
#
#
# status, site : master Rongcheng
# length of timespace : 1000001 || length of signal : 1000001 || length of signal_e : 1000001
# master process over; next_start_time : 10000
#
# status, site : slave Xuancheng
# slave process; end time : 13459.7
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 10000 end time : 13459.7
#
# shape of temp : (345971,) shape of temp_signal : (345971,)
# last temp : 13459.7 last -1 temp : 13459.69
# before last timespace : 10000.0 before last -1 timespace : 9999.99
#
# after last timespace : 13459.7 after last -1 timespace 13459.69
#
# length of timespace : 1345971 || length of signal : 1345971 || length of signal_e : 1345971
#
# length of timespace : 2145972 || length of signal : 2145972 || length of signal_e : 2145972
# slave process over; start_time : 21459.7
# last time : 21459.7 last -1 time : 21459.690000000002
#
# status, site : slave Helong
# slave process; end time : 30852.32
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 21459.7 end time : 30852.32
#
# shape of temp : (939262,) shape of temp_signal : (939262,)
# last temp : 30852.32 last -1 temp : 30852.309999989353
# before last timespace : 21459.7 before last -1 timespace : 21459.690000000002
#
# after last timespace : 30852.32 after last -1 timespace 30852.309999989353
#
# length of timespace : 3085233 || length of signal : 3085233 || length of signal_e : 3085233
#
# length of timespace : 3885234 || length of signal : 3885234 || length of signal_e : 3885234
# slave process over; start_time : 38852.32
# last time : 38852.32 last -1 time : 38852.31
#
#
# iteration over
# --------------------------------------------------
#
# last time : 74299.98999999999 last -1 time : 74299.98000000001
# standard_time : 74300
# length of timespace : 7430001 || length of signal : 7430001 || length of signal_e : 7430001
#
# --------------------------------------------------
#
# tau : 0
# length of time space : 100001 1000.0 999.99
# length of master_window : 100001
# length of master_window_e : 100001
# tau : 1000
# length of time space : 200001 2000.0 1999.99
# length of master_window : 200001
# length of master_window_e : 200001
# tau : 2000
# length of time space : 300001 3000.0 2999.99
# length of master_window : 300001
# length of master_window_e : 300001
# tau : 3000
# length of time space : 400001 4000.0 3999.99
# length of master_window : 400001
# length of master_window_e : 400001
# tau : 4000
# length of time space : 500001 5000.0 4999.99
# length of master_window : 500001
# length of master_window_e : 500001
# tau : 5000
# length of time space : 600001 6000.0 5999.99
# length of master_window : 600001
# length of master_window_e : 600001
# tau : 6000
# length of time space : 700001 7000.0 6999.99
# length of master_window : 700001
# length of master_window_e : 700001
# tau : 7000
# length of time space : 800001 8000.0 7999.99
# length of master_window : 800001
# length of master_window_e : 800001
# tau : 8000
# length of time space : 900001 9000.0 8999.99
# length of master_window : 900001
# length of master_window_e : 900001
# tau : 9000
# length of time space : 1000001 10000.0 9999.99
# length of master_window : 1000001
# length of master_window_e : 1000001
#
#
# status, site : master Rongcheng
# length of timespace : 8430002 || length of signal : 8430002 || length of signal_e : 8430002
# master process over; next_start_time : 84300
#
# status, site : slave Xuancheng
# slave process; end time : 87759.7
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 84300 end time : 87759.7
#
# shape of temp : (345970,) shape of temp_signal : (345970,)
# last temp : 87759.7 last -1 temp : 87759.68999997109
# before last timespace : 84300.0 before last -1 timespace : 84299.99
#
# after last timespace : 87759.7 after last -1 timespace 87759.68999997109
#
# length of timespace : 8775971 || length of signal : 8775971 || length of signal_e : 8775971
#
# length of timespace : 9575972 || length of signal : 9575972 || length of signal_e : 9575972
# slave process over; start_time : 95759.7
# last time : 95759.7 last -1 time : 95759.69
#
# status, site : slave Helong
# slave process; end time : 105152.32
# emission delay ; Add dummy zero signals
# ----------------------------------
# start time : 95759.7 end time : 105152.32
#
# shape of temp : (939263,) shape of temp_signal : (939263,)
# last temp : 105152.32 last -1 temp : 105152.31000000001
# before last timespace : 95759.7 before last -1 timespace : 95759.69
#
# after last timespace : 105152.32 after last -1 timespace 105152.31000000001
#
# length of timespace : 10515234 || length of signal : 10515234 || length of signal_e : 10515234
#
# length of timespace : 11315235 || length of signal : 11315235 || length of signal_e : 11315235
# slave process over; start_time : 113152.32
# last time : 113152.32 last -1 time : 113152.31000000001
#
#
# iteration over
# --------------------------------------------------
#
# last time : 148600.0 last -1 time : 148599.9899999972
# standard_time : 148600
# length of timespace : 14860002 || length of signal : 14860002 || length of signal_e : 14860002
#
# --------------------------------------------------
